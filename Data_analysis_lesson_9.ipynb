# %% [markdown]
# <a href="https://colab.research.google.com/github/Terrykamau/Python/blob/main/Data_analysis_lesson_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import statsmodels.api as sm

# %%
df=sm.datasets.get_rdataset('EuroEnergy','AER',cache=True).data
df.reset_index(inplace=True)
print(df.head())
# Out:
#   rownames    gdp  energy
# 0  Austria  45451   30633
# 1  Belgium  62049   58894
# 2   Cyprus   2003    1211
# 3  Denmark  34540   27049
# 4  Finland  28388   26405

# %%
world=gpd.read_file('/content/ne_110m_admin_0_countries.shp')
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# /tmp/ipython-input-2687124978.py in <cell line: 0>()
# ----> 1 world=gpd.read_file('/content/ne_110m_admin_0_countries.shp')
#
# /usr/local/lib/python3.12/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     314
#     315     if engine == "pyogrio":
# --> 316         return _read_file_pyogrio(
#     317             filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318         )
#
# /usr/local/lib/python3.12/dist-packages/geopandas/io/file.py in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     574         kwargs["columns"] = kwargs.pop("include_fields")
#     575
# --> 576     return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#     577
#     578
#
# ...
